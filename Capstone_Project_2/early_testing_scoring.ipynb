# %% [markdown]
# # First Test of The Model With Scoring Method
#
# Testing the model after training it on one of the forty files in the dataset. Unfortunately the trained model is takes about 1GB so  cannot upload it to github.

# %%
import gensim
import pandas as pd
import numpy as np

# %% [markdown]
# Loading the filtered dataset

# %%
data_dir = './data/csvTrain/'
filename = 's2-corpus-002_lang_cites.csv'

# %%
df = pd.read_csv(data_dir+filename)

# %% [markdown]
# Finding a paper from PRL (I have some domain knowledge in the field):

# %%
df[df.journalName.str.contains('review letters')].head()
# Out:
#       Unnamed: 0  Unnamed: 0.1                                        id  \
# 1885        1917          1917  c367c5744775fa3d79404e1a5ad8cb0f9107655f
# 2906        2952          2952  3758ce746008b7d6ccc06d49e57a235a4c21c6f0
# 6320        6422          6422  202dd914cbaadbd5ee76c1ddc919750f949c669b
# 8949        9082          9082  e93d5a8632797df8201733ff347f81e5cc3ef5a8
# 9290        9427          9427  1384974a2b790d01ffa237bd084eec0af62688f7
#
#                                           paperAbstract  \
# 1885  The branching fraction ratio R(D^{*})≡B(B[over...
# 2906  We grew tetragonally distorted FexCo1-x alloy ...
# 6320  We introduce state-independent, nonperturbativ...
# 8949  In this study we report on jumps in the magnet...
# 9290  Quantum teleportation faces increasingly deman...
#
#                                                   title    year  \
# 1885  Measurement of the ratio of branching fraction...  2015.0
# 2906  Perpendicular magnetic anisotropy induced by t...  2006.0
# 6320  Quantum Speed Limits for Leakage and Decoherence.  2015.0
# 8949  Interaction-induced partitioning and magnetiza...  2011.0
# 9290  Remote preparation of single-photon "hybrid" e...  2010.0
#
#                   journalName  numCites     lang
# 1885  Physical review letters         1  English
# 2906  Physical review letters         3  English
# 6320  Physical review letters         5  English
# 8949  Physical review letters         0  English
# 9290  Physical review letters        24  English

# %% [markdown]
# 4195 seems promising. It's quantum mechanics and according to the abstract I would put it in either a condensed matter journal or physical chemistry journal (as this kind of quantum calculation are heavily used in computational chemistry) (ie. PRL, PRE, journal of chemical physics PCCP or somthing like that)<br>
# Loading the model and finding the top 500 similar abstracts:

# %%
from gensim.models.word2vec import Word2Vec
model= Word2Vec.load('./models/doc2vec/doc2vec_one_file_filter.model')

# %%
sims = model.docvecs.most_similar(df.iloc[6320].id, topn=500)
sims_id = [n for n,v in sims]
sims_score = np.exp(np.array([v for n,v in sims])*30)

# %%
df_sims = df[df.id.isin(sims_id)]
df_sims['score'] = sims_score
# Out:
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.iloc[6320].paperAbstract
# Out:
# 'We introduce state-independent, nonperturbative Hamiltonian quantum speed limits for population leakage and fidelity loss, for a gapped open system interacting with a reservoir. These results hold in the presence of initial correlations between the system and the reservoir, under the sole assumption that their interaction and its commutator with the reservoir Hamiltonian are norm bounded. The reservoir need not be thermal and can be time dependent. We study the significance of energy mismatch between the system and the local degrees of freedom of the reservoir that directly interact with the system. We demonstrate that, in general, by increasing the system gap we may reduce this energy mismatch, and, consequently, drive the system and the reservoir into resonance; this can accelerate fidelity loss, irrespective of the thermal properties or state of the reservoir. This implies that quantum error suppression strategies based on increasing the gap are not uniformly beneficial. Our speed limits also yield an elementary lower bound on the relaxation time of spin systems.'

# %%
df_sims.iloc[1].paperAbstract
# Out:
# 'Despite the considerable evidence showing that dispersal between habitat patches is often asymmetric, most of the metapopulation models assume symmetric dispersal. In this paper, we develop a Monte Carlo simulation model to quantify the effect of asymmetric dispersal on metapopulation persistence. Our results suggest that metapopulation extinctions are more likely when dispersal is asymmetric. Metapopulation viability in systems with symmetric dispersal mirrors results from a mean field approximation, where the system persists if the expected per patch colonization probability exceeds the expected per patch local extinction rate. For asymmetric cases, the mean field approximation underestimates the number of patches necessary for maintaining population persistence. If we use a model assuming symmetric dispersal when dispersal is actually asymmetric, the estimation of metapopulation persistence is wrong in more than 50% of the cases. Metapopulation viability depends on patch connectivity in symmetric systems, whereas in the asymmetric case the number of patches is more important. These results have important implications for managing spatially structured populations, when asymmetric dispersal may occur. Future metapopulation models should account for asymmetric dispersal, while empirical work is needed to quantify the patterns and the consequences of asymmetric dispersal in natural metapopulations.'

# %%
from sklearn.preprocessing import MinMaxScaler
def score_sites(df_sims, citesWeight=.1, yearWeight = 1, scoreWeight = 0.1):
    """
    The scoring function. 
    For rach abstract the number of citations, published year and model score are scaled
    and a weighted sum defines the final score. The abstracts are then aggragates by jurnal 
    and the sum of papers from each journal is multiplied by the mean score for the abstracts from 
    this journal to get the final ranking
    
    @citesWeight : weight for the number of citations
    @yearWeight : weight for the publication year
    @scoreWeight : model score 
    
    @returns: a pandas DataFrame with the journal ranking.
    """
    scaler = MinMaxScaler()

    scaledCites = scaler.fit_transform(np.array([df_sims.numCites]).T)
    scaledYear = scaler.fit_transform(np.array([df_sims.year]).T)
    scaledScore = scaler.fit_transform(np.array([df_sims.score]).T)
    df_sims['combinedScore'] = (citesWeight * scaledCites + yearWeight * scaledYear + scoreWeight * scaledScore).flatten()

    groups =df_sims.groupby('journalName')
    df_sims2 = pd.DataFrame(groups.id.count())
    df_sims2['meanCites'] = groups.numCites.mean()
    df_sims2['meanScore'] = groups.score.mean()
    df_sims2['combinedScoreMean'] = groups.combinedScore.mean()
    df_sims2 = df_sims2[df_sims2.id > 3]
    df_sims2['finalScore'] =  df_sims2.id *df_sims2.combinedScoreMean
    return df_sims2

# %%
df_sims2 = score_sites(df_sims)
df_sims2.sort_values(by='finalScore', ascending=False).head(20)
# Out:
# /home/itay/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                     id  meanCites  \
# journalName
# The Journal of chemical physics                     26   3.769231
# Physical review. E, Statistical, nonlinear, and...  19   4.631579
# Physical review letters                             17   3.705882
# CoRR                                                13   1.846154
# Proceedings of the National Academy of Sciences...  14  13.928571
# Physical review. E                                   7   0.285714
# Journal of the American Chemical Society             8   3.500000
# Journal of physics. Condensed matter : an Insti...   7   1.142857
# The journal of physical chemistry. B                 7   4.714286
# Journal of chemical theory and computation           6   0.833333
# Physical chemistry chemical physics : PCCP           6   1.000000
# Soft matter                                          5   0.400000
# Nano letters                                         4   2.250000
# Nanoscale                                            4   3.250000
# Biophysical journal                                  4   7.500000
# SIAM J. Scientific Computing                         4  12.000000
# Nature                                               5  35.800000
#
#                                                       meanScore  \
# journalName
# The Journal of chemical physics                     2671.006723
# Physical review. E, Statistical, nonlinear, and...  2676.943138
# Physical review letters                             3031.382269
# CoRR                                                4231.727015
# Proceedings of the National Academy of Sciences...  2306.292477
# Physical review. E                                  2140.031539
# Journal of the American Chemical Society            2119.064206
# Journal of physics. Condensed matter : an Insti...  2120.546383
# The journal of physical chemistry. B                2223.644915
# Journal of chemical theory and computation          2646.387752
# Physical chemistry chemical physics : PCCP          3450.247338
# Soft matter                                         2580.493077
# Nano letters                                        4105.707525
# Nanoscale                                           2509.177060
# Biophysical journal                                 3428.263621
# SIAM J. Scientific Computing                        2689.751645
# Nature                                              3634.442072
#
#                                                     combinedScoreMean  \
# journalName
# The Journal of chemical physics                              0.869952
# Physical review. E, Statistical, nonlinear, and...           0.804445
# Physical review letters                                      0.812170
# CoRR                                                         0.914250
# Proceedings of the National Academy of Sciences...           0.799270
# Physical review. E                                           0.965802
# Journal of the American Chemical Society                     0.796398
# Journal of physics. Condensed matter : an Insti...           0.852909
# The journal of physical chemistry. B                         0.843937
# Journal of chemical theory and computation                   0.950170
# Physical chemistry chemical physics : PCCP                   0.930111
# Soft matter                                                  0.957591
# Nano letters                                                 0.917398
# Nanoscale                                                    0.911267
# Biophysical journal                                          0.828382
# SIAM J. Scientific Computing                                 0.785514
# Nature                                                       0.521067
#
#                                                     finalScore
# journalName
# The Journal of chemical physics                      22.618740
# Physical review. E, Statistical, nonlinear, and...   15.284459
# Physical review letters                              13.806895
# CoRR                                                 11.885255
# Proceedings of the National Academy of Sciences...   11.189775
# Physical review. E                                    6.760612
# Journal of the American Chemical Society              6.371184
# Journal of physics. Condensed matter : an Insti...    5.970365
# The journal of physical chemistry. B                  5.907562
# Journal of chemical theory and computation            5.701019
# Physical chemistry chemical physics : PCCP            5.580667
# Soft matter                                           4.787953
# Nano letters                                          3.669591
# Nanoscale                                             3.645069
# Biophysical journal                                   3.313529
# SIAM J. Scientific Computing                          3.142055
# Nature                                                2.605334

# %% [markdown]
# PRL is there, and most of the journals are in either condensed matter or physical chemistry. There are obviosly not enough samples and using the full dataset should fix that. I also need of think of a way to normalize things by the total number of publication in a journal (i.e if there is a publication with tons of papers that are somwhat similar to our abstract it will be ranked high)
#
# Next, lets try a random abstract from 'Human Genetics' I pulled from google:

# %%
abst = 'Single nucleotide polymorphisms (SNPs) constitute the bulk of human genetic variation, occurring with an average density of ∼1/1000 nucleotides of a genotype. SNPs are either neutral allelic variants or are under selection of various strengths, and the impact of SNPs on fitness remains unknown. Identification of SNPs affecting human phenotype, especially leading to risks of complex disorders, is one of the key problems of medical genetics. SNPs in protein-coding regions that cause amino acid variants (non-synonymous cSNPs) are most likely to affect phenotypes. We have developed a straightforward and reliable method based on physical and comparative considerations that estimates the impact of an amino acid replacement on the three-dimensional structure and function of the protein. We estimate that ∼20% of common human non-synonymous SNPs damage the protein. The average minor allele frequency of such SNPs in our data set was two times lower than that of benign non-synonymous SNPs. The average human genotype carries approximately 103 damaging non-synonymous SNPs that together cause a substantial reduction in fitness.'

# %%
abst2 = abst.lower().split(' ')

# %%
bb = model.infer_vector(abst2)

# %%
sims = model.docvecs.most_similar(positive=[model.infer_vector(abst2)], topn=5000)
sims_id = [n for n,v in sims]
sims_score = np.exp(np.array([v for n,v in sims])*30)

# %%
df_sims = df[df.id.isin(sims_id)]
df_sims['score'] = sims_score
# Out:
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_sims2 = score_sites(df_sims)
df_sims2.sort_values(by='finalScore', ascending=False).head(20)
df_sims2.sort_values(by='finalScore', ascending=False).head(20)
# Out:
# /home/itay/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                     id   meanCites  \
# journalName
# Proceedings of the National Academy of Sciences...  67   77.313433
# The Journal of biological chemistry                 53   23.698113
# Genetics                                            29   19.931034
# Gene                                                27    9.370370
# Methods in molecular biology                        21    3.000000
# Genome research                                     23   55.434783
# Journal of chromatography. B, Analytical techno...  21    5.666667
# American journal of human genetics                  23   37.347826
# Human molecular genetics                            22   55.409091
# CoRR                                                19    6.157895
# Biochemical and biophysical research communicat...  23    9.956522
# Nature                                              21  103.904762
# Human Genetics                                      24   13.458333
# Bioinformatics                                      17   29.588235
# Journal of virology                                 18   26.888889
# Genomics                                            22   16.363636
# Biochimica et biophysica acta                       18    6.277778
# Molecular ecology                                   16   26.250000
# Evolution; international journal of organic evo...  17    8.294118
# Cancer research                                     18   30.333333
#
#                                                      meanScore  \
# journalName
# Proceedings of the National Academy of Sciences...  585.738023
# The Journal of biological chemistry                 674.159148
# Genetics                                            623.716554
# Gene                                                659.067914
# Methods in molecular biology                        631.041874
# Genome research                                     534.222207
# Journal of chromatography. B, Analytical techno...  574.547938
# American journal of human genetics                  509.190381
# Human molecular genetics                            508.513719
# CoRR                                                674.727007
# Biochemical and biophysical research communicat...  506.961788
# Nature                                              657.930751
# Human Genetics                                      640.136044
# Bioinformatics                                      413.572523
# Journal of virology                                 470.958427
# Genomics                                            634.849661
# Biochimica et biophysica acta                       513.751839
# Molecular ecology                                   430.313467
# Evolution; international journal of organic evo...  707.525476
# Cancer research                                     881.302274
#
#                                                     combinedScoreMean  \
# journalName
# Proceedings of the National Academy of Sciences...           0.748110
# The Journal of biological chemistry                          0.719510
# Genetics                                                     0.763917
# Gene                                                         0.805058
# Methods in molecular biology                                 0.912570
# Genome research                                              0.827040
# Journal of chromatography. B, Analytical techno...           0.860456
# American journal of human genetics                           0.782092
# Human molecular genetics                                     0.816138
# CoRR                                                         0.941688
# Biochemical and biophysical research communicat...           0.764098
# Nature                                                       0.777841
# Human Genetics                                               0.675303
# Bioinformatics                                               0.909227
# Journal of virology                                          0.845229
# Genomics                                                     0.674449
# Biochimica et biophysica acta                                0.790589
# Molecular ecology                                            0.877124
# Evolution; international journal of organic evo...           0.821984
# Cancer research                                              0.751289
#
#                                                     finalScore
# journalName
# Proceedings of the National Academy of Sciences...   50.123371
# The Journal of biological chemistry                  38.134025
# Genetics                                             22.153597
# Gene                                                 21.736559
# Methods in molecular biology                         19.163968
# Genome research                                      19.021928
# Journal of chromatography. B, Analytical techno...   18.069574
# American journal of human genetics                   17.988120
# Human molecular genetics                             17.955032
# CoRR                                                 17.892069
# Biochemical and biophysical research communicat...   17.574249
# Nature                                               16.334668
# Human Genetics                                       16.207276
# Bioinformatics                                       15.456861
# Journal of virology                                  15.214118
# Genomics                                             14.837881
# Biochimica et biophysica acta                        14.230609
# Molecular ecology                                    14.033979
# Evolution; international journal of organic evo...   13.973735
# Cancer research                                      13.523205

# %% [markdown]
# I have absolutly no knoladge in the field but it seems reasonable.
#
# Lastly, I'm gonna try one of my papers:

# %%
abst= 'The main challenge in predicting sliding friction is related to the complexity of highly \
nonequilibrium processes, the kinetics of which are controlled by the interface temperature. \
Our experiments reveal a nonmonotonic enhancement of dry nanoscale friction at cryogenic \
temperatures for different material classes. Concerted simulations show that it emerges from \
two competing processes acting at the interface: the thermally activated formation as well as \
rupturing of an ensemble of atomic contacts. These results provide a new conceptual \
framework to describe the dynamics of dry friction'

# %%
abst2 = abst.lower().split(' ')
bb = model.infer_vector(abst2)
sims = model.docvecs.most_similar(positive=[model.infer_vector(abst2)], topn=5000)
sims_id = [n for n,v in sims]
sims_score = np.exp(np.array([v for n,v in sims])*30)
df_sims = df[df.id.isin(sims_id)]
df_sims['score'] = sims_score

df_sims2 = score_sites(df_sims)
df_sims2.sort_values(by='finalScore', ascending=False).head(20)
df_sims2.sort_values(by='finalScore', ascending=False).head(20)
# Out:
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/itay/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/itay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                      id  meanCites  \
# journalName
# The Journal of biological chemistry                 115  14.721739
# Langmuir : the ACS journal of surfaces and coll...   97   2.453608
# The Journal of chemical physics                      92   1.347826
# Proceedings of the National Academy of Sciences...   94  25.691489
# Physical chemistry chemical physics : PCCP           79   1.113924
# Journal of the American Chemical Society             83   5.831325
# Physical review. E, Statistical, nonlinear, and...   76   2.578947
# The journal of physical chemistry. B                 73   2.534247
# ACS applied materials & interfaces                   60   1.750000
# Biochemistry                                         81  10.209877
# Biochimica et biophysica acta                        59   9.135593
# Journal of colloid and interface science             50   1.400000
# The journal of physical chemistry. A                 50   1.640000
# Biophysical journal                                  53  14.094340
# ACS nano                                             40   5.525000
# Nature                                               48  47.520833
# Chemistry                                            39   1.897436
# Angewandte Chemie                                    36   3.805556
# Inorganic chemistry                                  40   0.725000
# Journal of nanoscience and nanotechnology            36   0.416667
#
#                                                      meanScore  \
# journalName
# The Journal of biological chemistry                 825.957468
# Langmuir : the ACS journal of surfaces and coll...  710.381089
# The Journal of chemical physics                     567.726906
# Proceedings of the National Academy of Sciences...  599.895766
# Physical chemistry chemical physics : PCCP          670.419540
# Journal of the American Chemical Society            682.779292
# Physical review. E, Statistical, nonlinear, and...  783.665615
# The journal of physical chemistry. B                694.160339
# ACS applied materials & interfaces                  615.797727
# Biochemistry                                        717.293664
# Biochimica et biophysica acta                       681.707172
# Journal of colloid and interface science            700.779914
# The journal of physical chemistry. A                676.548949
# Biophysical journal                                 530.505440
# ACS nano                                            859.960683
# Nature                                              572.692240
# Chemistry                                           871.365486
# Angewandte Chemie                                   596.084947
# Inorganic chemistry                                 560.573021
# Journal of nanoscience and nanotechnology           579.276128
#
#                                                     combinedScoreMean  \
# journalName
# The Journal of biological chemistry                          0.774179
# Langmuir : the ACS journal of surfaces and coll...           0.888147
# The Journal of chemical physics                              0.883199
# Proceedings of the National Academy of Sciences...           0.814914
# Physical chemistry chemical physics : PCCP                   0.927414
# Journal of the American Chemical Society                     0.880732
# Physical review. E, Statistical, nonlinear, and...           0.856364
# The journal of physical chemistry. B                         0.877880
# ACS applied materials & interfaces                           0.957149
# Biochemistry                                                 0.693466
# Biochimica et biophysica acta                                0.784324
# Journal of colloid and interface science                     0.876742
# The journal of physical chemistry. A                         0.874729
# Biophysical journal                                          0.788062
# ACS nano                                                     0.920618
# Nature                                                       0.732593
# Chemistry                                                    0.879217
# Angewandte Chemie                                            0.925665
# Inorganic chemistry                                          0.832169
# Journal of nanoscience and nanotechnology                    0.889923
#
#                                                     finalScore
# journalName
# The Journal of biological chemistry                  89.030574
# Langmuir : the ACS journal of surfaces and coll...   86.150222
# The Journal of chemical physics                      81.254343
# Proceedings of the National Academy of Sciences...   76.601876
# Physical chemistry chemical physics : PCCP           73.265734
# Journal of the American Chemical Society             73.100780
# Physical review. E, Statistical, nonlinear, and...   65.083641
# The journal of physical chemistry. B                 64.085263
# ACS applied materials & interfaces                   57.428913
# Biochemistry                                         56.170750
# Biochimica et biophysica acta                        46.275132
# Journal of colloid and interface science             43.837089
# The journal of physical chemistry. A                 43.736453
# Biophysical journal                                  41.767264
# ACS nano                                             36.824732
# Nature                                               35.164482
# Chemistry                                            34.289454
# Angewandte Chemie                                    33.323929
# Inorganic chemistry                                  33.286755
# Journal of nanoscience and nanotechnology            32.037226

# %% [markdown]
# Now I get the journal of biological chemistry as the first result which is an error, but the rest of them are more accurate. It is also noticable that the score of this journal is much lower then the average its just the shear amount of papers there that tips the scale. I still need to compensate for journals with lots of papers in them...

# %% [markdown]
# So... This needs more work, but it seems like it's going in the right direction. Next I'll train a Glove model and test the mean vectors distance for similarity, there is some reaserch which suggests this can work better for short documents)
